# %% [markdown]
# # **PART 1: Data Cleaning/Examination**

# %% [markdown]
# **Question 1:** Load the *Iris.csv* file in the Colab and *read* it as a dataframe.

# %%
# Provide your solution here
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **Question 2:** Examine the data schema by printing the *types* of data for each column. Provide the answer for each question.

# %%
# Provide your solution here



# How many columns do we have? ____

# What type is the data type of the variety? ______
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %% [markdown]
# **Question 3:** Continue examinig the dataset, let us focus on the numerical data, columns include:
# *  sepal.length -> float64
# *  sepal.width -> float64
# *  petal.length -> float64
# *  petal.width -> float64
#
# Describe the dataset and answer the following questions

# %%
# Provide your solution here



# What is float64? _________ * Feel free to search online!
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# **Question 4:** Print the last 3 rows of your dataframe.

# %%
# Provide your solution here
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %% [markdown]
# **Question 5:** Use the *isnull().sum()* method to examine the dataset for empty rows. Do we have any empty rows?

# %%
# Provide your solution here



# Do we have any missing data? ____________
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %% [markdown]
# **Question 6:** Provide a script to count how many data cells there are in the dataframe for each caterogy (group by variety).

# %%
# Provide your solution here
# Out:
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# dtype: int64

# %% [markdown]
# 🚨
#
# There are 50 records for each category Setosa, Versicolor and Virginica. There are not empty cells, so our dataset is ready to further steps.

# %% [markdown]
# # **PART 2: Data Modelling**

# %% [markdown]
# **Question 7:** We will need to split our dataset into feature data (X) and target data (y). As discussed in class the feature data is the data that our machine learning model will *learn* in order to classify according to the target variable. These are:
# *  sepal.length
# *  sepal.width
# *  petal.length
# *  petal.width
#
# Extract the data for the first four columns and store it in a new dataframe called *iris_data_feature_data*.

# %%
# Provide your solution here
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# **Question 8:** Now we will need to create the *iris_data_target_data* dataframe. The new dataframe will store only the target values.

# %%
# Provide your solution here
# Out:
#        variety
# 0       Setosa
# 1       Setosa
# 2       Setosa
# 3       Setosa
# 4       Setosa
# ..         ...
# 145  Virginica
# 146  Virginica
# 147  Virginica
# 148  Virginica
# 149  Virginica
#
# [150 rows x 1 columns]

# %% [markdown]
# **Question 9:** Study and run the following code.

# %%
X_count = iris_data_feature_data.count() 
y_count = iris_data_target_data.count()

print("X counts")
print(X_count)

print("y count")
print(y_count)
# Out:
# X counts
# sepal.length    150
# sepal.width     150
# petal.length    150
# petal.width     150
# dtype: int64
# y count
# variety    150
# dtype: int64

# %% [markdown]
# 💡 There are 150 rows for both *iris_data_feature_data* and *iris_data_target_data*. Note, that we cannot proceed with modeling if the counts do not match as we will receive an error! All X data should have the same number of rows as the y data.

# %% [markdown]
# **Question 10:** As seen in class, create an X and y variable to represent iris_data_feature_data and iris_data_target_data respectively.
#
# Here, we just create two variables for representing X and y for our model.

# %%
# Provide your solution here

# %% [markdown]
# **Question 11:** Create your KNN model and fit it using the X and y variables from the previous step. Use the *KNeighborsClassifier* including 4 neighbors.

# %%
# Provide your solution here
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=4, p=2,
#                      weights='uniform')

# %% [markdown]
# The output of this script provides some details about the default setup of the KNN model.

# %% [markdown]
# **Question 12:** What is the *metric='minkowski'*? Look online and keep a note of your findings.

# %%
# Provide a short text here

# 
#
#

# %% [markdown]
# **Question 13:** Provide a script to *predict* the class of a flower with the following data:
# *  sepal.length = 4.5
# *  sepal.width = 3.2
# *  petal.length = 1.1
# *  petal.width = 0.4

# %%
# Examine the following code

knn.predict([[4.5, 3.2, 1.1, 0.4]])
# Out:
# array(['Setosa'], dtype=object)

# %% [markdown]
# **Question 14:** Print the data for row 4 and compare with the prediction of the previous step. Then answer the questions.

# %%
# Provide your solution here

# Compare data from question 13 and data for row 4, Do they look similar? 
# ________________________

# Is the prediction of question 13 a good prediction?
# ________________________
# Out:
# sepal.length         5
# sepal.width        3.6
# petal.length       1.4
# petal.width        0.2
# variety         Setosa
# Name: 4, dtype: object

# %% [markdown]
# # **PART 3: Evaluation of results (manual)**

# %% [markdown]
# There are different ways to evaluate the efficiency of a machine learning model. Today, we will do it empirically by examining the data and plotting diagrams to evaluate results by the eye. In the future, we will look for more automated ways of testing.

# %% [markdown]
# **Question 15:** Plot a boxplor for the *iris_data* by *variety*. This will plot four diagrams for each feature and the associated confidence intervals per variety.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.figure()
iris_data.boxplot(by="variety", figsize=(15, 10))
plt.show()

# %% [markdown]
# **Question 16:** Consider the following unknown data:
# *  sepal.length = 6.9
# *  sepal.width = 3.0
# *  petal.length = 4.6
# *  petal.width = 1.5
#
# Using the boxplot that you just created. By looking the plots, what kind of flower is this? Setosa, Versicolor or Virginica?

# %%
# It looks __________

# %% [markdown]
#  The following diagram shows the unknown data.

# %% [markdown]
# ![Capture1.PNG](data:image/png;base64,...)

# %% [markdown]
# **Question 15:** Provide a script to *predict* the class of a flower with the following data:
# *  sepal.length = 6.9
# *  sepal.width = 3.0
# *  petal.length = 4.6
# *  petal.width = 1.5
#
# Is this prediction as expected?

# %%
# Provide your solution here


# This prediction was (goor or bad?) ________
# I predicted: ___________ 
# My model predicted: _________
# Out:
# array(['Versicolor'], dtype=object)

# %% [markdown]
# **Question 16:** Provide a script to *predict* the class of a flower with the following data:
# *  sepal.length = 5.9
# *  sepal.width = 3.0
# *  petal.length = 5.5
# *  petal.width = 2
#
# Bsaed on the boxplot diagram, is this prediction as expected?

# %%
# Provide your solution here


# This prediction was (goor or bad?) ________
# I predicted: ___________ 
# My model predicted: _________
# Out:
# array(['Virginica'], dtype=object)

# %% [markdown]
# **Question 17:** Study and run the following code. Is there any problem here?

# %%
print(knn.predict([[6.5, 3.75, 5.2, 1.5]]))
print(knn.predict([[6.5, 3.75, 5.3, 1.5]]))

# Almost similar data could print different results!
# Out:
# ['Versicolor']
# ['Virginica']

# %% [markdown]
# **Question 18:** Create a pairplot for the Iris dataset (*iris_data*) using as hue the *variety*.
#
#
# Revise the class slides on how to set markers *markers=["o", "s", "D"]*
#
# Did you spot any problems?

# %%
# Study the following code

sns.pairplot(iris_data, hue = "variety", height=3, markers=["o", "s", "D"])
plt.show()

# %% [markdown]
# Pairplot is a very useful way to compare overalapping values, the distributions demonstrate how data is overalapping for all the possible combinations of the feature data.

# %% [markdown]
# ![Capture2.PNG](data:image/png;base64,...)

# %% [markdown]
# **Question 19:** Plot a diagram to show a scatterplot of the *iris_data* using x as *sepal.length* and as y the *sepal.width*. Use the *variety* as hue.

# %%
# Study the following code

sns.lmplot(x='sepal.length', y='sepal.width', data=iris_data, fit_reg=False, hue='variety', height=10, scatter_kws={"s": 100}) 

sns.lmplot(x='sepal.length', y='sepal.width', data=iris_data, fit_reg=False, hue='variety', height=10, scatter_kws={"s":100})
